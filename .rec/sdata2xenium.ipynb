# %%
import sopa
import spatialdata

sdata = spatialdata.read_zarr("/Volumes/ProstateCancerEvo_SpatialAnalysis/dbs/Region_1_Xenium_Phen_HE_Integrated.V1.zarr")
# Out:
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# /Users/ugursahin/miniforge3/envs/SOPA/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /Users/ugursahin/miniforge3/envs/SOPA/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /Users/ugursahin/miniforge3/envs/SOPA/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /Users/ugursahin/miniforge3/envs/SOPA/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# ...

# %%
sdata
# Out:
# SpatialData object, with associated Zarr store: /Volumes/ProstateCancerEvo_SpatialAnalysis/dbs/Region_1_Xenium_Phen_HE_Integrated.V1.zarr
# ├── Images
# │     ├── 'HE': DataTree[cyx] (3, 6926, 21997), (3, 3464, 10999), (3, 1731, 5500), (3, 866, 2750), (3, 433, 1375), (3, 216, 687)
# │     ├── 'PhenoCycler_Image': DataTree[cyx] (25, 6391, 20981), (25, 3195, 10490), (25, 1597, 5245), (25, 798, 2622), (25, 399, 1311)
# │     └── 'Xenium_Image': DataTree[cyx] (5, 17141, 51168), (5, 8570, 25584), (5, 4285, 12792), (5, 2142, 6396), (5, 1071, 3198)
# ├── Labels
# │     ├── 'cell_labels': DataTree[yx] (17141, 51168), (8570, 25584), (4285, 12792), (2142, 6396), (1071, 3198)
# │     └── 'nucleus_labels': DataTree[yx] (17141, 51168), (8570, 25584), (4285, 12792), (2142, 6396), (1071, 3198)
# ├── Points
# │     └── 'transcripts': DataFrame with shape: (<Delayed>, 13) (3D points)
# ├── Shapes
# │     ├── 'cell_boundaries': GeoDataFrame shape: (113273, 1) (2D shapes)
# ...

# %%
sopa.io.explorer.write("/Volumes/ProstateCancerEvo_SpatialAnalysis/dbs/Region_1_Xenium_Phen_HE_Integrated.V1", sdata, image_key="Xenium_Image", shapes_key="cell_boundaries",points_key="transcripts", table_key="table")
# Out:
# [INFO] (sopa.io.explorer.table) Writing table with 5101 columns
# [INFO] (sopa.io.explorer.table) Writing 2 cell categories: segmentation_method, region
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sopa.io.explorer.write("/Volumes/ProstateCancerEvo_SpatialAnalysis/dbs/Region_1_Xenium_Phen_HE_Integrated.V1", sdata, image_key="Xenium_Image", shapes_key="cell_boundaries",points_key="transcripts", table_key="table")
#
# File ~/miniforge3/envs/SOPA/lib/python3.10/site-packages/sopa/io/explorer/converter.py:141, in write(path, sdata, table_key, image_key, shapes_key, points_key, gene_column, pixel_size, layer, polygon_max_vertices, lazy, ram_threshold_gb, mode, save_h5ad, run_name)
#     138     geo_df = to_intrinsic(sdata, geo_df, image_key)
#     140     if table_key in sdata.tables:
# ...
