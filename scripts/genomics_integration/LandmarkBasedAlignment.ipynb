# %%
import spatialdata

sdata_main = spatialdata.read_zarr("/Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/Region2_Xenium_Phen_HE_Integrated.V4.ongoing.zarr")
sdata_genomics = spatialdata.read_zarr("/Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/ARMS/Region2_FULL_TilesAdded.zarr")
# Out:
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# /Users/ugursahin/miniforge3/envs/SOPA/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /Users/ugursahin/miniforge3/envs/SOPA/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /Users/ugursahin/miniforge3/envs/SOPA/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /Users/ugursahin/miniforge3/envs/SOPA/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# ...

# %%
sdata_main
# Out:
# SpatialData object, with associated Zarr store: /Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/Region2_Xenium_Phen_HE_Integrated.V4.ongoing.zarr
# ├── Images
# │     ├── 'HE_Image': DataTree[cyx] (3, 14052, 23906), (3, 7026, 11953), (3, 3513, 5977), (3, 1757, 2989), (3, 878, 1494), (3, 439, 747)
# │     ├── 'PhenoCycler_Image': DataTree[cyx] (25, 12563, 22914), (25, 6281, 11457), (25, 3140, 5728), (25, 1570, 2864), (25, 785, 1432)
# │     └── 'Xenium_Image': DataTree[cyx] (4, 34103, 54036), (4, 17051, 27018), (4, 8525, 13509), (4, 4262, 6754), (4, 2131, 3377)
# ├── Points
# │     ├── 'HE_Marks': DataFrame with shape: (<Delayed>, 2) (2D points)
# │     └── 'transcripts': DataFrame with shape: (<Delayed>, 13) (3D points)
# ├── Shapes
# │     ├── 'cell_boundaries': GeoDataFrame shape: (299769, 1) (2D shapes)
# │     ├── 'cell_boundaries_Backup': GeoDataFrame shape: (299769, 1) (2D shapes)
# │     └── 'nucleus_boundaries': GeoDataFrame shape: (277431, 1) (2D shapes)
# └── Tables
# ...

# %%
sdata_genomics
# Out:
# SpatialData object, with associated Zarr store: /Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/ARMS/Region2_FULL_TilesAdded.zarr
# ├── Images
# │     └── '_20221020095443.ome': DataTree[cyx] (3, 114243, 79178), (3, 28560, 19794), (3, 7140, 4948), (3, 1785, 1237), (3, 446, 309)
# ├── Points
# │     └── 'ARMS_Marks': DataFrame with shape: (<Delayed>, 2) (2D points)
# └── Shapes
#       └── 'tiles': GeoDataFrame shape: (2109, 4) (2D shapes)
# with coordinate systems:
#     ▸ 'pixels', with elements:
#         _20221020095443.ome (Images), ARMS_Marks (Points), tiles (Shapes)

# %%
# from napari_spatialdata import Interactive
# Interactive([sdata_genomics,sdata_main])

# %%
from spatialdata.transformations import (
    align_elements_using_landmarks,
    get_transformation_between_landmarks,
)

affine = get_transformation_between_landmarks(
    references_coords=sdata_main["HE_Marks"], moving_coords=sdata_genomics["ARMS_Marks"]
)
affine
# Out:
# Affine (x, y -> x, y)
#     [ 4.92020554e-01 -1.05530656e+00  6.62231232e+04]
#     [ 1.05530656e+00  4.92020554e-01 -1.78100267e+04]
#     [0. 0. 1.]

# %%
affine = align_elements_using_landmarks(
    references_coords=sdata_main["HE_Marks"],
    moving_coords=sdata_genomics["ARMS_Marks"],

    
    reference_element=sdata_main["HE_Image"],
    moving_element=sdata_genomics["_20221020095443.ome"],
    reference_coordinate_system="global",
    moving_coordinate_system="pixels",
    new_coordinate_system="global",
)
affine
# Out:
# Sequence
#     Identity
#     Affine (x, y -> x, y)
#         [ 4.92020554e-01 -1.05530656e+00  6.62231232e+04]
#         [ 1.05530656e+00  4.92020554e-01 -1.78100267e+04]
#         [0. 0. 1.]

# %%
sdata_main
# Out:
# SpatialData object, with associated Zarr store: /Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/Region2_Xenium_Phen_HE_Integrated.V4.ongoing.zarr
# ├── Images
# │     ├── 'HE_Image': DataTree[cyx] (3, 14052, 23906), (3, 7026, 11953), (3, 3513, 5977), (3, 1757, 2989), (3, 878, 1494), (3, 439, 747)
# │     ├── 'PhenoCycler_Image': DataTree[cyx] (25, 12563, 22914), (25, 6281, 11457), (25, 3140, 5728), (25, 1570, 2864), (25, 785, 1432)
# │     └── 'Xenium_Image': DataTree[cyx] (4, 34103, 54036), (4, 17051, 27018), (4, 8525, 13509), (4, 4262, 6754), (4, 2131, 3377)
# ├── Points
# │     ├── 'HE_Marks': DataFrame with shape: (<Delayed>, 2) (2D points)
# │     └── 'transcripts': DataFrame with shape: (<Delayed>, 13) (3D points)
# ├── Shapes
# │     ├── 'cell_boundaries': GeoDataFrame shape: (299769, 1) (2D shapes)
# │     ├── 'cell_boundaries_Backup': GeoDataFrame shape: (299769, 1) (2D shapes)
# │     └── 'nucleus_boundaries': GeoDataFrame shape: (277431, 1) (2D shapes)
# └── Tables
# ...

# %%
from spatialdata import SpatialData
from spatialdata.transformations import (
    BaseTransformation,
    Sequence,
    get_transformation,
    set_transformation,
)


def postpone_transformation(
    sdata: SpatialData,
    transformation: BaseTransformation,
    source_coordinate_system: str,
    target_coordinate_system: str,
):
    for element_type, element_name, element in sdata._gen_elements():
        old_transformations = get_transformation(element, get_all=True)
        if source_coordinate_system in old_transformations:
            old_transformation = old_transformations[source_coordinate_system]
            sequence = Sequence([old_transformation, transformation])
            set_transformation(element, sequence, target_coordinate_system)


postpone_transformation(
    sdata=sdata_genomics,
    transformation=affine,
    source_coordinate_system="pixels",
    target_coordinate_system="global",
)

# %%
element = sdata_genomics["_20221020095443.ome"]
sdata_main.images["_20221020095443.ome"] = element


element_2=sdata_genomics["tiles"]
sdata_main.shapes["tiles"] = element_2

# %%
from napari_spatialdata import Interactive

Interactive(sdata_main)
# Out:
# 2025-06-04 14:11:01.389 python[7866:1665754] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-06-04 14:11:01.389 python[7866:1665754] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %%
#sdata_main.write("/Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/Region2_Xenium_Phen_HE_Integrated.ARMS_aligned.V5.ongoing.zarr")
# Out:
# INFO     The SpatialData object is not self-contained (i.e. it contains some elements that are Dask-backed from
#          locations outside
#          /Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/Region2_Xenium_Phen_HE_Integrated.ARMS_aligned.V5.ongoi
#          ng.zarr). Please see the documentation of `is_self_contained()` to understand the implications of working
#          with SpatialData objects that are not self-contained.
# INFO     The Zarr backing store has been changed from
#          /Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/Region2_Xenium_Phen_HE_Integrated.V4.ongoing.zarr the
#          new file path:
#          /Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/Region2_Xenium_Phen_HE_Integrated.ARMS_aligned.V5.ongoi
#          ng.zarr

# %%
# sdata_genomics.write_element("ARMS_Marks")
# sdata_main.write_element("HE_Marks")
#visium_sdata.write_transformations()
#xenium_sdata.write_transformations()

# %% [markdown]
# ## Extract TILES

# %%
# Specify axes in the order the image stores them, e.g. ("x", "y")
max_px = [55820, 30070]
min_px = [783, 762]

# Crop: this filters every element in sdata (images, shapes, tables) to that box
cropped_sdata = sdata_main.query.bounding_box(
    min_coordinate=min_px,
    max_coordinate=max_px,
    axes=("x", "y"),
    target_coordinate_system="global",
    filter_table=True
)
# Out:
# /Users/ugursahin/miniforge3/envs/SOPA/lib/python3.10/functools.py:889: UserWarning: The object has `points` element. Depending on the number of points, querying MAY suffer from performance issues. Please consider filtering the object before calling this function by calling the `subset()` method of `SpatialData`.
#   return dispatch(args[0].__class__)(*args, **kw)

# %%
import napari_spatialdata

napari_spatialdata.Interactive(cropped_sdata)
# Out:
# INFO: Please wait for the current operation to finish.
# 2025-06-04 14:14:45.197 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-06-04 14:14:45.256 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-06-04 14:14:53.856 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-06-04 14:14:53.860 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
cropped_sdata.shapes["tiles"].to_csv("Tiles_In_R2.csv")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Let's do opposite !

# %%
from spatialdata.transformations import (
    align_elements_using_landmarks,
    get_transformation_between_landmarks,
)

affine = get_transformation_between_landmarks(
    moving_coords=sdata_main["HE_Marks"], references_coords=sdata_genomics["ARMS_Marks"]
)
affine
# Out:
# Affine (x, y -> x, y)
#     [ 3.62234735e-01  7.76936431e-01 -1.01270685e+04]
#     [-7.76936431e-01  3.62234735e-01  5.79937131e+04]
#     [0. 0. 1.]

# %%
affine = align_elements_using_landmarks(
    moving_coords=sdata_main["HE_Marks"],
    references_coords=sdata_genomics["ARMS_Marks"],

    
    moving_element = sdata_main["cell_boundaries"],
    reference_element = sdata_genomics["_20221020095443.ome"],

    moving_coordinate_system="global",
    reference_coordinate_system="pixels",
    new_coordinate_system="aligned",
) 
affine
# Out:
# Sequence
#     Scale (x, y)
#         [4.70588235 4.70588235]
#     Affine (x, y -> x, y)
#         [ 3.62234735e-01  7.76936431e-01 -1.01270685e+04]
#         [-7.76936431e-01  3.62234735e-01  5.79937131e+04]
#         [0. 0. 1.]

# %%
sdata_genomics
# Out:
# SpatialData object, with associated Zarr store: /Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/ARMS/Region2_FULL_TilesAdded.zarr
# ├── Images
# │     └── '_20221020095443.ome': DataTree[cyx] (3, 114243, 79178), (3, 28560, 19794), (3, 7140, 4948), (3, 1785, 1237), (3, 446, 309)
# ├── Points
# │     └── 'ARMS_Marks': DataFrame with shape: (<Delayed>, 2) (2D points)
# └── Shapes
#       └── 'tiles': GeoDataFrame shape: (2109, 4) (2D shapes)
# with coordinate systems:
#     ▸ 'aligned', with elements:
#         _20221020095443.ome (Images)
#     ▸ 'pixels', with elements:
#         _20221020095443.ome (Images), ARMS_Marks (Points), tiles (Shapes)

# %%
element = sdata_main["cell_boundaries"]
sdata_genomics.shapes["cell_boundaries"] = element

# %%
sdata_genomics
# Out:
# SpatialData object, with associated Zarr store: /Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/ARMS/Region2_FULL_TilesAdded.zarr
# ├── Images
# │     └── '_20221020095443.ome': DataTree[cyx] (3, 114243, 79178), (3, 28560, 19794), (3, 7140, 4948), (3, 1785, 1237), (3, 446, 309)
# ├── Points
# │     └── 'ARMS_Marks': DataFrame with shape: (<Delayed>, 2) (2D points)
# └── Shapes
#       ├── 'cell_boundaries': GeoDataFrame shape: (299769, 1) (2D shapes)
#       └── 'tiles': GeoDataFrame shape: (2109, 4) (2D shapes)
# with coordinate systems:
#     ▸ 'aligned', with elements:
#         _20221020095443.ome (Images), cell_boundaries (Shapes)
#     ▸ 'global', with elements:
#         cell_boundaries (Shapes)
#     ▸ 'pixels', with elements:
#         _20221020095443.ome (Images), ARMS_Marks (Points), tiles (Shapes)
# with the following elements not in the Zarr store:
#     ▸ cell_boundaries (Shapes)

# %%
import napari_spatialdata

napari_spatialdata.Interactive(sdata_genomics)
# Out:
# 2025-06-03 23:40:29.663 python[86712:1367410] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-06-03 23:40:29.663 python[86712:1367410] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# /Users/ugursahin/miniforge3/envs/SOPA/lib/python3.10/site-packages/multiscale_spatial_image/operations/operations.py:18: FutureWarning: Passing 'method, tolerance, copy, fill_value' as positional argument(s) to reindex was deprecated in version v2023.10.0 and will raise an error two releases later. Please pass them as keyword arguments.
#   return ds["image"].reindex(*args, **kwargs).to_dataset()
# /Users/ugursahin/miniforge3/envs/SOPA/lib/python3.10/site-packages/multiscale_spatial_image/operations/operations.py:18: FutureWarning: Passing 'method, tolerance, copy, fill_value' as positional argument(s) to reindex was deprecated in version v2023.10.0 and will raise an error two releases later. Please pass them as keyword arguments.
# ...

# %%
from spatialdata.transformations import Identity, set_transformation

element = sdata_genomics.shapes["tiles"]

set_transformation(element, Identity(), to_coordinate_system="aligned")

# %%
sdata_genomics
# Out:
# SpatialData object, with associated Zarr store: /Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/ARMS/Region2_FULL_TilesAdded.zarr
# ├── Images
# │     └── '_20221020095443.ome': DataTree[cyx] (3, 114243, 79178), (3, 28560, 19794), (3, 7140, 4948), (3, 1785, 1237), (3, 446, 309)
# ├── Points
# │     └── 'ARMS_Marks': DataFrame with shape: (<Delayed>, 2) (2D points)
# └── Shapes
#       ├── 'cell_boundaries': GeoDataFrame shape: (299769, 1) (2D shapes)
#       └── 'tiles': GeoDataFrame shape: (2109, 4) (2D shapes)
# with coordinate systems:
#     ▸ 'aligned', with elements:
#         _20221020095443.ome (Images), cell_boundaries (Shapes), tiles (Shapes)
#     ▸ 'global', with elements:
#         cell_boundaries (Shapes)
#     ▸ 'pixels', with elements:
#         _20221020095443.ome (Images), ARMS_Marks (Points), tiles (Shapes)
# with the following elements not in the Zarr store:
#     ▸ cell_boundaries (Shapes)

# %%
from spatialdata import polygon_query

tiles = sdata_genomics.shapes["tiles"]
#tiles[tiles["name"] == "plate4_2G"].geometry
poi, name = tiles.geometry.iloc[104], tiles.name.iloc[104]
sample = polygon_query(sdata_genomics, polygon=poi, target_coordinate_system="aligned")

# %%
sample
# Out:
# SpatialData object
# ├── Images
# │     └── '_20221020095443.ome': DataTree[cyx] (3, 1256, 1334), (3, 314, 334), (3, 78, 84), (3, 20, 21), (3, 5, 5)
# └── Shapes
#       ├── 'cell_boundaries': GeoDataFrame shape: (551, 1) (2D shapes)
#       └── 'tiles': GeoDataFrame shape: (1, 4) (2D shapes)
# with coordinate systems:
#     ▸ 'aligned', with elements:
#         _20221020095443.ome (Images), cell_boundaries (Shapes), tiles (Shapes)
#     ▸ 'global', with elements:
#         cell_boundaries (Shapes)
#     ▸ 'pixels', with elements:
#         _20221020095443.ome (Images), tiles (Shapes)

# %%
## Run for all
collectedTiles = dict()
for idx in range(sdata_genomics.shapes["tiles"].shape[0]):
    try:
        poi, name = sdata_genomics["tiles"].geometry.iloc[idx], sdata_genomics["tiles"].name.iloc[idx]
        print(poi, name)
        collectedTiles[name] = polygon_query(sdata_genomics, polygon=poi, target_coordinate_system="aligned").shapes["cell_boundaries"].values
    except:
        print(f"{name} is skipped ! ")
# Out:
# POLYGON ((9405.65 63208.47, 9111.15 63238.9, 8816.38 63269.68, 8521.25 63300.51, 8295.21 63323.88, 8225.77 63331.36, 8201.23 63334.01, 8220.68 63598.53, 8240.11 63863.11, 8259.55 64127.38, 8278.97 64391.38, 8280.73 64413.94, 8575.16 64382.57, 8869.63 64351.19, 9163.78 64320.15, 9457.57 64288.86, 9481.97 64286.5, 9463.24 64023.09, 9444.5 63759.39, 9425.76 63495.41, 9406.98 63231.12, 9405.65 63208.47)) plate4_7B
# POLYGON ((16618.29 50269.2, 16325.47 50292.29, 16032.32 50315.76, 15738.83 50339.26, 15514.46 50356.98, 15445.03 50362.79, 15420.96 50364.81, 15436.29 50638.73, 15451.99 50912.66, 15467.65 51186.3, 15483.35 51459.64, 15484.8 51483.36, 15777.6 51459.27, 16070.43 51435.13, 16362.89 51411.06, 16655.07 51387.01, 16679.7 51385.25, 16664.34 51112.57, 16649.34 50839.54, 16634.32 50566.24, 16619.29 50292.63, 16618.29 50269.2)) plate4_4A
# ...

# %%
poi, name = tiles.geometry.iloc[104], tiles.name.iloc[104]
sample = polygon_query(sdata_genomics, polygon=poi, target_coordinate_system="aligned")
sample
# Out:
# SpatialData object
# ├── Images
# │     └── '_20221020095443.ome': DataTree[cyx] (3, 1256, 1334), (3, 314, 334), (3, 78, 84), (3, 20, 21), (3, 5, 5)
# └── Shapes
#       ├── 'cell_boundaries': GeoDataFrame shape: (551, 1) (2D shapes)
#       └── 'tiles': GeoDataFrame shape: (1, 4) (2D shapes)
# with coordinate systems:
#     ▸ 'aligned', with elements:
#         _20221020095443.ome (Images), cell_boundaries (Shapes), tiles (Shapes)
#     ▸ 'global', with elements:
#         cell_boundaries (Shapes)
#     ▸ 'pixels', with elements:
#         _20221020095443.ome (Images), tiles (Shapes)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
sample.shapes["cell_boundaries"].index.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['aaabfngm-1', 'aaabfngn-1', 'aaabfngo-1', 'aaabfngp-1', 'aaabfnha-1',
#        'aaabfnhb-1', 'aaabfnhc-1', 'aaabfnhd-1', 'aaabfnhe-1', 'aaabfnhf-1',
#        ...
#        'aaadlgmg-1', 'aaadlgmh-1', 'aaadlgmi-1', 'aaadlgmo-1', 'aaadlgno-1',
#        'aaadlgnp-1', 'aaadlgoa-1', 'aaaeimcb-1', 'aaaeimce-1', 'aaaeimcg-1'],
#       dtype='object', length=551)>

# %%
sdata_genomics.write("/Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/ARMS/Region2_FULL_TilesAdded.CellsAdded.zarr")
# Out:
# INFO     The SpatialData object is not self-contained (i.e. it contains some elements that are Dask-backed from
#          locations outside
#          /Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/ARMS/Region2_FULL_TilesAdded.CellsAdded.zarr). Please
#          see the documentation of `is_self_contained()` to understand the implications of working with SpatialData
#          objects that are not self-contained.
# INFO     The Zarr backing store has been changed from
#          /Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/ARMS/Region2_FULL_TilesAdded.zarr the new file path:
#          /Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/ARMS/Region2_FULL_TilesAdded.CellsAdded.zarr

# %%
import napari_spatialdata

napari_spatialdata.Interactive(sample)
# Out:
# 2025-06-04 00:04:27.832 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-06-04 00:04:29.540 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2025-06-04 00:04:29.543 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# /Users/ugursahin/miniforge3/envs/SOPA/lib/python3.10/site-packages/multiscale_spatial_image/operations/operations.py:18: FutureWarning: Passing 'method, tolerance, copy, fill_value' as positional argument(s) to reindex was deprecated in version v2023.10.0 and will raise an error two releases later. Please pass them as keyword arguments.
#   return ds["image"].reindex(*args, **kwargs).to_dataset()
# ...

# %%
# from spatialdata import SpatialData
# from spatialdata.transformations import (
#     BaseTransformation,
#     Sequence,
#     get_transformation,
#     set_transformation,
# )


# def postpone_transformation(
#     sdata: SpatialData,
#     transformation: BaseTransformation,
#     source_coordinate_system: str,
#     target_coordinate_system: str,
# ):
#     for element_type, element_name, element in sdata._gen_elements():
#         old_transformations = get_transformation(element, get_all=True)
#         if source_coordinate_system in old_transformations:
#             old_transformation = old_transformations[source_coordinate_system]
#             sequence = Sequence([old_transformation, transformation])
#             set_transformation(element, sequence, target_coordinate_system)


# postpone_transformation(
#     sdata=sdata_main,
#     transformation=affine,
#     source_coordinate_system="global",
#     target_coordinate_system="aligned",
# )

# %%
sdata_genomics
# Out:
# SpatialData object, with associated Zarr store: /Volumes/ProstateCancerEvoMain/dbs/Ongoing/Region2/ARMS/Region2_FULL_TilesAdded.zarr
# ├── Images
# │     └── '_20221020095443.ome': DataTree[cyx] (3, 114243, 79178), (3, 28560, 19794), (3, 7140, 4948), (3, 1785, 1237), (3, 446, 309)
# ├── Points
# │     └── 'ARMS_Marks': DataFrame with shape: (<Delayed>, 2) (2D points)
# └── Shapes
#       ├── 'cell_boundaries': GeoDataFrame shape: (299769, 1) (2D shapes)
#       └── 'tiles': GeoDataFrame shape: (2109, 4) (2D shapes)
# with coordinate systems:
#     ▸ 'aligned', with elements:
#         _20221020095443.ome (Images), ARMS_Marks (Points), cell_boundaries (Shapes), tiles (Shapes)
#     ▸ 'global', with elements:
#         cell_boundaries (Shapes)
#     ▸ 'pixels', with elements:
#         _20221020095443.ome (Images), ARMS_Marks (Points), tiles (Shapes)
# with the following elements not in the Zarr store:
#     ▸ cell_boundaries (Shapes)
