# %% [markdown]
# ## Genomics Integration by TILEs

# %%
import scanpy as sc
import spatialdata

Tissue = "Region2"
TableFolder = "REGION2_TABLES"

adata = sc.read_h5ad(f"/Volumes/ProstateCancerEvoMain/dbs/Ongoing/{Tissue}/{TableFolder}/{Tissue}_Xenium_Phen_HE_Integrated.GeneTranscripts_XStock_Native.V1.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 299769 × 5101
# ...

# %%
## 
adata_for_annotation = adata = sc.read_h5ad(f'/Volumes/ProstateCancerEvoMain/dbs/Ongoing/Collection/MajorAnnGroups/Results/{Tissue}/{Tissue}.AnnDc.All.h5ad')
#adata.obs["assigned_celltype"] = adata_for_annotation.obs["assigned_celltype"].values

# %%
# 1. Grab the existing obs DataFrame
obs = adata_for_annotation.obs

# 2. Loop over every integer index from 0 to 299,768 (inclusive)
for i in range(0, 299_769):
    if str(i) not in obs.index:
        print(i)
        # If index i is missing, create a new row at obs.loc[i]
        # and set only 'assigned_celltype' to None.
        # Any other columns will default to NaN.
        obs.loc[i, "assigned_celltype"] = None

# 3. (Optional) If you want to keep the final index sorted ascending:
obs.sort_index(inplace=True)

# 4. Write back to adata
adata_for_annotation.obs = obs
# Out:
# 4
# 116
# 178
# 181
# 186
# 384
# 414
# 428
# 432
# 457
# 508
# 565
# 578
# 740
# 748
# 812
# 813
# 814
# 887
# 890
# 891
# 892
# 920
# 972
# 973
# 990
# 991
# 1003
# 1021
# 1032
# 1034
# 1035
# 1039
# 1044
# 1045
# 1050
# 1053
# 1057
# 1061
# 1068
# 1139
# 1140
# 1198
# 1235
# 1269
# 1285
# 1389
# 1474
# 1599
# 1650
# 1654
# 1687
# 1691
# 1698
# 1709
# 1712
# 1713
# 1724
# 1733
# 1753
# 1766
# 1771
# 1785
# 1792
# 1797
# 1812
# 1818
# 1825
# 1827
# 1828
# 1829
# 1852
# 1855
# 1861
# 1864
# 1865
# 1883
# 1894
# 1912
# 1915
# 1926
# 1996
# 2018
# 2031
# 2034
# 2036
# 2052
# 2054
# 2055
# 2075
# 2091
# 2095
# 2099
# 2103
# 2125
# 2131
# 2172
# 2180
# 2189
# 2206
# 2254
# 2305
# 2360
# 2376
# 2446
# 2456
# 2484
# 2485
# 2492
# 2495
# 2571
# 2574
# 2590
# 2599
# 2601
# 2604
# 2607
# 2617
# 2618
# 2619
# 2621
# 2624
# 2678
# 2682
# 2753
# 2755
# 2756
# 2767
# 2774
# 2775
# 2776
# 2797
# 2819
# 2841
# 2843
# 2864
# 2866
# 2887
# 2888
# 2890
# 2891
# 2892
# 2895
# 2911
# 2919
# 2978
# 2980
# ...

# %%
adata_for_annotation.obs["assigned_celltype"]
# Out:
# 1                                      CD8 T Cell
# 5                              CD8 and CD4 T Cell
# 6                                      CD4 T Cell
# 7                                      CD4 T Cell
# 8                                      CD4 T Cell
#                            ...
# 299693                         tumor_cell_markers
# 299725                         tumor_cell_markers
# 299727                         tumor_cell_markers
# 299767    basal_epithelial_cell_of_prostatic_duct
# 299768        luminal_cell_of_prostate_epithelium
# Name: assigned_celltype, Length: 266502, dtype: category
# Categories (20, object): ['Bcell', 'CD4 T Cell', 'CD8 T Cell', 'CD8 and CD4 T Cell', ..., 'pericyte', 'prostate_gland_microvascular_endothelial_cell', 'smooth_muscle_cell_of_prostate', 'tumor_cell_markers']

# %%
mask = adata.obs["cell_type_xenium_panel"] == "tumor_cell_markers"
adata = adata[mask, :].copy()

# %%
import pandas as pd

TILEs = pd.read_csv("/Users/ugursahin/ProstateCancerEvo_SpatialAnalysis/scripts/genomics_integration/Barcode_TileClone_Pair.csv")
TILEs
