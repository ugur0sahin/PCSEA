# %%
install.packages("anndata")
library(Seurat)
library(reticulate)
library(anndata)


f <- "/Volumes/ProstateCancerEvoMain/Remote/ext/R-Container/.results/R4.seu.rds"
f <- "/Users/ugursahin/Downloads/R4.seu.rds"
seu <- readRDS(f)
seu
# Out:
# The downloaded binary packages are in
# 	/var/folders/4p/7h_929nx5qngrf9z7xhfy15w0000gn/T//RtmpCcnDij/downloaded_packages
# Warning message in readRDS(f):
# "strings not representable in native encoding will be translated to UTF-8"
# An object of class Seurat
# 6421 features across 310003 samples within 6 assays
# Active assay: PhenCyc (25 features, 25 variable features)
#  3 layers present: counts, data, scale.data
#  5 other assays present: Xenium, BlankCodeword, ControlCodeword, ControlProbe, GenomicControl
#  3 dimensional reductions calculated: pca_Xenium, pca_PhenCyc, wnn.umap
#  1 spatial field of view present: fov

# %%
lapply(c("dplyr","Seurat","HGNChelper","openxlsx"), library, character.only = T)

# load gene set preparation function
source("https://raw.githubusercontent.com/IanevskiAleksandr/sc-type/master/R/gene_sets_prepare.R")
# load cell type annotation function
source("https://raw.githubusercontent.com/IanevskiAleksandr/sc-type/master/R/sctype_score_.R")
source("https://raw.githubusercontent.com/IanevskiAleksandr/sc-type/master/R/sctype_wrapper.R"); 
source("https://raw.githubusercontent.com/IanevskiAleksandr/sc-type/master/R/gene_sets_prepare.R"); source("https://raw.githubusercontent.com/IanevskiAleksandr/sc-type/master/R/sctype_score_.R")


#db_ <- "/gpfs3/well/hamdy/projects/ugur/dbs/annotations/prostate_annotation_markers.xlsx";
db_ <- "/Volumes/ProstateCancerEvoMain/Remote/dbs/annotations/prostate_annotation_markers_V5.xlsx"

tissue <- "Prostate" # e.g. Immune system,Pancreas,Liver,Eye,Kidney,Brain,Lung,Adrenal,Heart,Intestine,Muscle,Placenta,Spleen,Stomach,Thymus
# Out:
# [[1]]
#  [1] "openxlsx"     "HGNChelper"   "dplyr"        "anndata"      "reticulate"
#  [6] "Seurat"       "SeuratObject" "sp"           "stats"        "graphics"
# [11] "grDevices"    "utils"        "datasets"     "methods"      "base"
#
# [[2]]
#  [1] "openxlsx"     "HGNChelper"   "dplyr"        "anndata"      "reticulate"
#  [6] "Seurat"       "SeuratObject" "sp"           "stats"        "graphics"
# [11] "grDevices"    "utils"        "datasets"     "methods"      "base"
#
# [[3]]
#  [1] "openxlsx"     "HGNChelper"   "dplyr"        "anndata"      "reticulate"
#  [6] "Seurat"       "SeuratObject" "sp"           "stats"        "graphics"
# [11] "grDevices"    "utils"        "datasets"     "methods"      "base"
#
# [[4]]
#  [1] "openxlsx"     "HGNChelper"   "dplyr"        "anndata"      "reticulate"
#  [6] "Seurat"       "SeuratObject" "sp"           "stats"        "graphics"
# [11] "grDevices"    "utils"        "datasets"     "methods"      "base"

# %%
gs_list <- gene_sets_prepare(db_, tissue)
gs_list
# Out:
# Warning message in checkGeneSymbols(markers_all):
# "x contains non-approved gene symbols"
# Warning message in checkGeneSymbols(markers_all):
# "x contains non-approved gene symbols"
# Warning message in checkGeneSymbols(markers_all):
# "x contains non-approved gene symbols"
# Warning message in checkGeneSymbols(markers_all):
# "x contains non-approved gene symbols"
# Warning message in checkGeneSymbols(markers_all):
# "x contains non-approved gene symbols"
# Warning message in checkGeneSymbols(markers_all):
# "x contains non-approved gene symbols"
# Warning message in checkGeneSymbols(markers_all):
# "x contains non-approved gene symbols"
# Warning message in checkGeneSymbols(markers_all):
# "x contains non-approved gene symbols"
# Warning message in checkGeneSymbols(markers_all):
# "x contains non-approved gene symbols"
# Warning message in checkGeneSymbols(markers_all):
# "x contains non-approved gene symbols"
# Warning message in checkGeneSymbols(markers_all):
# ...

# %%
pbmc <- seu

# %%
options(future.globals.maxSize = 1 * 1024^3)


seurat_package_v5 <- isFALSE('counts' %in% names(attributes(pbmc[["Xenium"]])));
print(sprintf("Seurat object %s is used", ifelse(seurat_package_v5, "v5", "v4")))

# extract scaled scRNA-seq matrix
scRNAseqData_scaled <-  as.matrix(pbmc[["Xenium"]]$scale.data)

# run ScType
es.max <- sctype_score(scRNAseqData = scRNAseqData_scaled, scaled = TRUE, gs = gs_list$gs_positive, gs2 = gs_list$gs_negative)
# Out:
# [1] "Seurat object v5 is used"
